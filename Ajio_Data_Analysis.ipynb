# %%
#Ajio data analysis


#Pandas - data manipulation
#Seaborn and Matplotlib - Visualization

# %%
import pandas as pd #to use pandas

customers = pd.read_csv('customer.csv') #to call csv file in python data frame
customers
# Out:
#              C_ID             C_Name  Gender  Age       City           State  \
# 0     CS_11000001        Manbir Lala    Male   67      Delhi           Delhi
# 1     CS_11000002       Radhika More  Female   51       Pune     Maharashtra
# 2     CS_11000003       Faqid Halder  Female   57  Bengaluru       Karnataka
# 3     CS_11000004    Chandresh Dugar  Female   26      Thane     Maharashtra
# 4     CS_11000005         Logan Soni    Male   24  Ghaziabad   Uttar Pradesh
# ...           ...                ...     ...  ...        ...             ...
# 9995  CS_11009996       Lakshit Bose    Male   42      Delhi           Delhi
# 9996  CS_11009997       Ekaraj Kapur    Male   55    Kolkata     West Bengal
# 9997  CS_11009998         Jhalak Raj  Female   26  Ghaziabad   Uttar Pradesh
# 9998  CS_11009999       Faraj Shukla    Male   24     Indore  Madhya Pradesh
# 9999  CS_11010000  Indrajit Zacharia  Female   39      Surat         Gujarat
#
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   C_ID            10000 non-null  object
#  1   C_Name          10000 non-null  object
#  2   Gender          10000 non-null  object
#  3   Age             10000 non-null  int64
#  4   City            10000 non-null  object
#  5   State           10000 non-null  object
#  6   Street_Address  10000 non-null  object
#  7   Mobile          10000 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 625.1+ KB

# %%
delivery = pd.read_csv('delivery.csv')
ratings = pd.read_csv('ratings.csv')
orders = pd.read_csv('orders.csv')
products = pd.read_csv('products.csv')
returns = pd.read_csv('returns.csv')
transactions = pd.read_csv('transaction.csv')
delivery
# Out:
#          DP_ID       DP_name  DP_Ratings  Percent_Cut
# 0  DV_61000001     Delhivery           5           25
# 1  DV_61000002  Ecom Express           4           20
# 2  DV_61000003     Blue Dart           4           25
# 3  DV_61000004    Xpressbees           4           20
# 4  DV_61000005     Shadowfax           3           15

# %%
orders.describe()
# Out:
#                 Qty      Discount
# count  10000.000000  10000.000000
# mean       5.513600      9.066700
# std        2.882195     11.828941
# min        1.000000      0.000000
# 25%        3.000000      0.000000
# 50%        6.000000      0.000000
# 75%        8.000000     15.000000
# max       10.000000     50.000000

# %%
transactions.describe()
# Out:
#               Tr_ID        Or_ID Transaction_Mode Reward
# count         10000        10000            10000  10000
# unique        10000         6248                5      2
# top     TR_41009984  OR_31004020      Net Banking     No
# freq              1            6             2057   5024

# %%
transactions.head()
# Out:
#          Tr_ID        Or_ID Transaction_Mode Reward
# 0  TR_41000001  OR_31002037           Wallet     No
# 1  TR_41000002  OR_31008376           Wallet    Yes
# 2  TR_41000003  OR_31002152              UPI     No
# 3  TR_41000004  OR_31009239      Credit Card    Yes
# 4  TR_41000005  OR_31002891       Debit Card     No

# %%
#to chk for duplicates in ur database
orders.duplicated().sum()
transactions.duplicated().sum()
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
#if there are any duplicates use
orders = orders.drop_duplicates()

# %%
# check for null values

orders.isnull()
# Out:
#       Or_ID   C_ID   P_ID  Order_Date  Order_Time    Qty  Coupon  DP_ID  \
# 0     False  False  False       False       False  False   False  False
# 1     False  False  False       False       False  False   False  False
# 2     False  False  False       False       False  False   False  False
# 3     False  False  False       False       False  False   False  False
# 4     False  False  False       False       False  False   False  False
# ...     ...    ...    ...         ...         ...    ...     ...    ...
# 9995  False  False  False       False       False  False   False  False
# 9996  False  False  False       False       False  False   False  False
# 9997  False  False  False       False       False  False   False  False
# 9998  False  False  False       False       False  False   False  False
# 9999  False  False  False       False       False  False   False  False
#
#       Discount
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...

# %%
orders.isnull().sum()
# Out:
# Or_ID         0
# C_ID          0
# P_ID          0
# Order_Date    0
# Order_Time    0
# Qty           0
# Coupon        0
# DP_ID         0
# Discount      0
# dtype: int64

# %%
#if there are null
orders = orders.dropna()
#if numeric column use median to fill
#if textual col, use mode
#fill nulls - constant, mean, mode, ffill, bfill

orders["Qty"] = orders["Qty"].ffillna(orders["Qty"].median())
orders["Qty"] = orders["Qty"].ffill() #bfill
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-24-4141894225.py in <cell line: 0>()
#       5 #fill nulls - constant, mean, mode, ffill, bfill
#       6
# ----> 7 orders["Qty"] = orders["Qty"].ffillna(orders["Qty"].median())
#       8 orders["Qty"] = orders["Qty"].ffill() #bfill
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'ffillna'

# %%
#join tables
customers
# Out:
#              C_ID             C_Name  Gender  Age       City           State  \
# 0     CS_11000001        Manbir Lala    Male   67      Delhi           Delhi
# 1     CS_11000002       Radhika More  Female   51       Pune     Maharashtra
# 2     CS_11000003       Faqid Halder  Female   57  Bengaluru       Karnataka
# 3     CS_11000004    Chandresh Dugar  Female   26      Thane     Maharashtra
# 4     CS_11000005         Logan Soni    Male   24  Ghaziabad   Uttar Pradesh
# ...           ...                ...     ...  ...        ...             ...
# 9995  CS_11009996       Lakshit Bose    Male   42      Delhi           Delhi
# 9996  CS_11009997       Ekaraj Kapur    Male   55    Kolkata     West Bengal
# 9997  CS_11009998         Jhalak Raj  Female   26  Ghaziabad   Uttar Pradesh
# 9998  CS_11009999       Faraj Shukla    Male   24     Indore  Madhya Pradesh
# 9999  CS_11010000  Indrajit Zacharia  Female   39      Surat         Gujarat
#
# ...

# %%
orders.head()  #top 5
# Out:
#          Or_ID         C_ID         P_ID  Order_Date Order_Time  Qty  \
# 0  OR_31000001  CS_11005317  PD_21001301  2024-02-27   22:02:00    1
# 1  OR_31000002  CS_11000423  PD_21003593  2024-01-21   08:33:31    5
# 2  OR_31000003  CS_11001042  PD_21004315  2024-09-22   17:26:05    1
# 3  OR_31000004  CS_11004079  PD_21007443  2023-05-26   03:15:48   10
# 4  OR_31000005  CS_11009894  PD_21007621  2023-10-26   04:02:44    7
#
#       Coupon        DP_ID  Discount
# 0  No Coupon  DV_61000001         0
# 1       PULL  DV_61000002        25
# 2  No Coupon  DV_61000002         0
# 3  AGREEMENT  DV_61000003        10
# 4     WINDOW  DV_61000001        10
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Qty'].plot(kind='hist', bins=20, title='Qty')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['P_ID'].value_counts()
    for x_label, grp in _df_14.groupby('C_ID')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('C_ID')
_ = plt.ylabel('P_ID')

# %%
# joins

customers.head(2)
# Out:
#           C_ID        C_Name  Gender  Age   City        State  \
# 0  CS_11000001   Manbir Lala    Male   67  Delhi        Delhi
# 1  CS_11000002  Radhika More  Female   51   Pune  Maharashtra
#
#                               Street_Address      Mobile
# 0     Park Ave, 163 , Delhi , Delhi - 529675  9607971039
# 1  Elm St, 960 , Pune , Maharashtra - 328062  9109249091
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['Mobile'].plot(kind='hist', bins=20, title='Mobile')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Gender'].value_counts()
    for x_label, grp in _df_31.groupby('C_Name')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('C_Name')
_ = plt.ylabel('Gender')

# %%
orders.head(2)
# Out:
#          Or_ID         C_ID         P_ID  Order_Date Order_Time  Qty  \
# 0  OR_31000001  CS_11005317  PD_21001301  2024-02-27   22:02:00    1
# 1  OR_31000002  CS_11000423  PD_21003593  2024-01-21   08:33:31    5
#
#       Coupon        DP_ID  Discount
# 0  No Coupon  DV_61000001         0
# 1       PULL  DV_61000002        25

# %%
#to join two tables together, merge functio is used

merged_cust_ord = pd.merge(right = customers, left = orders, how = "inner", on = "C_ID")
merged_cust_ord
# Out:
#             Or_ID         C_ID         P_ID  Order_Date Order_Time  Qty  \
# 0     OR_31000001  CS_11005317  PD_21001301  2024-02-27   22:02:00    1
# 1     OR_31000002  CS_11000423  PD_21003593  2024-01-21   08:33:31    5
# 2     OR_31000003  CS_11001042  PD_21004315  2024-09-22   17:26:05    1
# 3     OR_31000004  CS_11004079  PD_21007443  2023-05-26   03:15:48   10
# 4     OR_31000005  CS_11009894  PD_21007621  2023-10-26   04:02:44    7
# ...           ...          ...          ...         ...        ...  ...
# 9995  OR_31009996  CS_11004842  PD_21004878  2024-11-14   18:20:50    5
# 9996  OR_31009997  CS_11005966  PD_21000725  2023-05-15   03:02:18    4
# 9997  OR_31009998  CS_11003081  PD_21002144  2024-12-28   17:50:17    6
# 9998  OR_31009999  CS_11006873  PD_21005870  2024-07-15   20:24:29    6
# 9999  OR_31010000  CS_11001833  PD_21001481  2023-01-11   23:07:12    6
#
#          Coupon        DP_ID  Discount             C_Name  Gender  Age  \
# ...

# %%
#summarize data....it creates pivot tables
gb = merged_cust_ord.groupby("State").agg({"Or_ID":"count"})
gb
# Out:
#                 Or_ID
# State
# Andhra Pradesh    554
# Bihar             510
# Delhi             424
# Gujarat          1551
# Karnataka         478
# Madhya Pradesh    977
# Maharashtra      1994
# Rajasthan         481
# Tamil Nadu        541
# Telangana         513
# Uttar Pradesh    1487
# West Bengal       490
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_38['Or_ID'].plot(kind='hist', bins=20, title='Or_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_39['Or_ID'].plot(kind='line', figsize=(8, 4), title='Or_ID')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_39['Or_ID'].plot(kind='line', figsize=(8, 4), title='Or_ID')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
gb = merged_cust_ord.groupby("State").agg({"Or_ID":"count"})
gb = gb.sort_values(by = "Or_ID", ascending= False) #sort data in desc by  total_order
gb
# Out:
#                 Or_ID
# State
# Maharashtra      1994
# Gujarat          1551
# Uttar Pradesh    1487
# Madhya Pradesh    977
# Andhra Pradesh    554
# Tamil Nadu        541
# Telangana         513
# Bihar             510
# West Bengal       490
# Rajasthan         481
# Karnataka         478
# Delhi             424

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x = gb.index, y = "Or_ID", data = gb, hue = gb.index, palette= "viridis")
plt.xticks(rotation = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (12,4))
sns.barplot(x = gb.index, y = "Or_ID", data = gb, hue = gb.index, palette= "spring")  #GnBu......#rocket    ....other colors
plt.xticks(rotation = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (12,4))
sns.barplot(x = gb.index, y = "Or_ID", data = gb, hue = gb.index, palette= "rocket")  #GnBu......#rocket    ....other colors
plt.xticks(rotation = 90)
plt.show()

# %%
gb = merged_cust_ord.groupby("State").agg({"Or_ID":"count"})
gb = gb.sort_values(by = "Or_ID", ascending= False) #sort data in desc by  total_order
gb
# Out:
#                 Or_ID
# State
# Maharashtra      1994
# Gujarat          1551
# Uttar Pradesh    1487
# Madhya Pradesh    977
# Andhra Pradesh    554
# Tamil Nadu        541
# Telangana         513
# Bihar             510
# West Bengal       490
# Rajasthan         481
# Karnataka         478
# Delhi             424
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# gb['Or_ID'].plot(kind='hist', bins=20, title='Or_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# gb['Or_ID'].plot(kind='line', figsize=(8, 4), title='Or_ID')
# plt.gca().spines[['top', 'right']].set_visible(False)
